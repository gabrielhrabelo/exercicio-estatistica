# %% [markdown]
# # Exercicio de estatística descritiva

# %% [markdown]
# [  ] - Média das vendas
# [  ] - Criar um gráfico de barras vertical mostrando o mes de referencia e o valor
# [  ] - Criar um grafico de linhas mostrando o mes de referencia e o valor
